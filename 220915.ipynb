# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
path =  "c:\\pytest\\"

# %%
with open(path+'금융규제운영규정.txt') as f:
    data = f.read()
print(data[:50])
# Out:
# 금융규제 운영규정
# [시행 2019. 1. 30.] [국무총리훈령 제734호, 2019. 1

# %%
refine_data = data.strip().replace("\n\n", "\n").replace("  ", " ")
print(refine_data[:200])
# Out:
# 금융규제 운영규정
# [시행 2019. 1. 30.] [국무총리훈령 제734호, 2019. 1. 30., 일부개정]
# 금융위원회(규제개혁법무담당관), 02-2100-2802
#     제1장 총칙
#  제1조(목적) 이 훈령은 금융위원회 및 금융유관기관이 금융회사등에 대한 금융규제를 신설·강화하거나 집행할 때 합리성·투명성·책임성을 확보하도록 함으로써 금융산업에서 경쟁

# %% [markdown]
# ### 명사류

# %%
import pandas as pd
import rhinoMorph
rn = rhinoMorph.startRhino()
morphs, poses = rhinoMorph.wholeResult_list(rn, refine_data, pos=['NNG', 'NNP', 'NNB', 'NP'], eomi=True, xrVv=True) # , combineN=True
nn = pd.DataFrame(set(morphs), columns=['명사류'])
nn.index.name = "index"
nn.to_csv(path+"220915_연습문제3_명사류.csv", index=False)
nn
# Out:
# filepath:  c:\projects\venv\lib\site-packages
# classpath:  c:\projects\venv\lib\site-packages\rhinoMorph/lib/rhino.jar
# JVM is already started~
# RHINO started!
#          명사류
# index
# 0         출금
# 1         규모
# 2        서비스
# 3         해석
# 4      근로소득세
# ...      ...
# 1090    전자거래
# 1091      제도
# 1092       칙
# 1093      사설
# 1094     인터넷
#
# [1095 rows x 1 columns]

# %% [markdown]
# ### 동사류

# %%
import pandas as pd
import rhinoMorph
rn = rhinoMorph.startRhino()
morphs, poses = rhinoMorph.wholeResult_list(rn, refine_data, pos=['VV'], eomi=True, xrVv=True) # , combineN=True
# print(morphs)
vv = pd.DataFrame(set(morphs), columns=['동사류'])
vv.index.name = "index"
vv.to_csv(path+"220915_연습문제3_동사류.csv", index=False)
vv
# Out:
# filepath:  c:\projects\venv\lib\site-packages
# classpath:  c:\projects\venv\lib\site-packages\rhinoMorph/lib/rhino.jar
# JVM is already started~
# RHINO started!
#         동사류
# index
# 0        서다
# 1      신설하다
# 2       밝히다
# 3       알리다
# 4      안전하다
# ...     ...
# 280     취하다
# 281    주어지다
# 282    강화하다
# 283    포함되다
# 284    적용하다
#
# [285 rows x 1 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
path =  "c:\\pytest\\"
with open(path+'금융규제운영규정.txt') as f:
    data = f.read()
refine_data = data.strip().replace("\n\n", "\n").replace("  ", " ")
sentences = [i.strip() for i in refine_data.split('\n')]
print(f"총 갯수: {len(sentences)}")
sentences[:10]
# Out:
# 총 갯수: 582
# ['금융규제 운영규정',
#  '[시행 2019. 1. 30.] [국무총리훈령 제734호, 2019. 1. 30., 일부개정]',
#  '금융위원회(규제개혁법무담당관), 02-2100-2802',
#  '제1장 총칙',
#  '제1조(목적) 이 훈령은 금융위원회 및 금융유관기관이 금융회사등에 대한 금융규제를 신설·강화하거나 집행할 때 합리성·투명성·책임성을 확보하도록 함으로써 금융산업에서 경쟁과 혁신을 촉진하는 데에 이바지함을 목적으로 한다.',
#  '제2조(정의) 이 훈령에서 사용하는 용어의 뜻은 다음 각 호와 같다.',
#  '1. "금융회사등"이란 다음 각 목의 자를 말한다.',
#  '가. 「은행법」에 따른 인가를 받아 설립된 은행(같은 법 제59조에 따라 은행으로 보는 자를 포함한다)',
#  '나. 「자본시장과 금융투자업에 관한 법률」에 따른 금융투자업자',
#  '다. 「보험업법」에 따른 보험회사(같은 법 제4조제6항에 따라 보험회사로 보는 자를 포함한다)']

# %%
# 금융이 들어간 단어만 출력, 저장
sentences_include_finance_word = []
for i in sentences:
    if('금융' in i):
        sentences_include_finance_word.append(i)
sentences_include_df = pd.DataFrame(set(sentences_include_finance_word), columns=['금융 포함 문장'])
sentences_include_df.to_csv(path+"220915_연습문제4_금융포함문장.csv", index=False)
sentences_include_df
# Out:
#                                               금융 포함 문장
# 0    ⑨ 그 밖에 금융회사 또는 전자금융업자의 클라우드컴퓨팅서비스 이용에 대해서는 「금융...
# 1    카. 관계 법령에 따라 금융회사등을 감독하거나 검사, 그 밖에 이와 비슷한 행정조사...
# 2    ⑧ 제2항의 절차를 거친 클라우드컴퓨팅서비스 제공자의 정보처리시스템이 위치한 전산실...
# 3    ② 금융위원회 및 금융감독원은 새로 임용된 공무원 또는 새로 채용된 직원에 대해서도...
# 4    ④ 금융위원회 및 금융감독원은 금융회사등이 금융행정지도에 따르지 아니하였다는 것만을...
# ..                                                 ...
# 279  7. "해킹"이라 함은 접근을 허가받지 아니하고 전자금융기반시설에 불법적으로 침투하...
# 280  ③ 금융회사 또는 전자금융업자는 대차대조표 등 중요 자료의 계상액과 각종 보조부·거...
# 281                           제3장 금융행정지도의 원칙ㆍ방식 및 절차 등
# 282  4. 금융회사등의 자산·자기자본 등의 규모, 위험관리체계 등을 고려하여 규제수준을 ...
# 283  4. 정보처리시스템의 운영담당, 개발담당 및 외부직원 등 업무 특성별로 네트워크를 ...
#
# [284 rows x 1 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
custom_find_words = ["금융", "투자"]

path =  "c:\\pytest\\"
with open(path+'금융규제운영규정.txt') as f:
    data = f.read()
refine_data = data.strip().replace("\n\n", "\n").replace("  ", " ")
sentences = [i.strip() for i in refine_data.split('\n')]
sentences_include_df = pd.DataFrame(sentences, columns=['문장'])
for word in custom_find_words:
    sentences_include_df[word]=""
    for n, i in enumerate(sentences):
        if(word in i):
            sentences_include_df.iloc[n:n+1,:].loc[:,word]="True"
        else:
            sentences_include_df.iloc[n:n+1,:].loc[:,word]="False"
sentences_include_df.to_csv(path+"220915_연습문제5_특정단어포함문장.csv", index=False)
sentences_include_df
# Out:
#                                                     문장     금융     투자
# 0                                            금융규제 운영규정   True  False
# 1    [시행 2019. 1. 30.] [국무총리훈령 제734호, 2019. 1. 30.,...  False  False
# 2                       금융위원회(규제개혁법무담당관), 02-2100-2802   True  False
# 3                                               제1장 총칙  False  False
# 4    제1조(목적) 이 훈령은 금융위원회 및 금융유관기관이 금융회사등에 대한 금융규제를 ...   True  False
# ..                                                 ...    ...    ...
# 577  2. 「정보보호산업의 진흥에 관한 법률」 제23조에 따라 지정된 정보보호전문서비스 ...  False  False
# 578                                        3. 침해사고대응기관  False  False
# 579                                   4. 금융위원장이 지정하는 자   True  False
# 580  ② 금융회사 및 전자금융업자는 시행령 제11조의5제3항에 따른 전자금융기반시설의 취...   True  False
# 581  ③ 금융위원장은 취약점 분석·평가 결과보고서에 근거하여 필요시 금융회사 및 전자금융...   True  False
#
# [582 rows x 3 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
pd.set_option('mode.chained_assignment',  None)

def find(obj_file, dst_file, find_words):
    '''
    find: 지정 파일로부터 특정단어를 찾아 dataframe형태로 출력해주는 모듈
    obj_file: 목적 대상 파일(txt 파일 권장, 인코딩 utf-8)
    dst_file: csv로 출력해 저장할 파일의 이름(출력을 안할때는 공백("")으로 할 것)
    find_words: 찾을 단어 list 입력
    ex) find_words_from_file('input.txt', './ouput.csv', ['word1', 'word2'])

    return 값: 결과 dataframe

    ---
    dependency: pandas
    '''
    with open(obj_file) as f:
        data = f.read()
    refine_data = data.strip().replace("\n\n", "\n").replace("  ", " ")
    sentences = [i.strip() for i in refine_data.split('\n')]
    sentences_include_df = pd.DataFrame(sentences, columns=['문장'])
    for word in find_words:
        sentences_include_df[word]=""
        for n, i in enumerate(sentences):
            if(word in i):
                sentences_include_df.iloc[n:n+1,:].loc[:,word]="True"
            else:
                sentences_include_df.iloc[n:n+1,:].loc[:,word]="False"
    if dst_file != "":
        sentences_include_df.to_csv(dst_file, index=False)
    return sentences_include_df

# %%
import find_words_from_file
path =  "c:\\pytest\\"
find_words_from_file.find(path+'금융규제운영규정.txt', path+'220915_연습문제6.csv', ['금융','법률'])
# Out:
#                                                     문장     금융     법률
# 0                                            금융규제 운영규정   True  False
# 1    [시행 2019. 1. 30.] [국무총리훈령 제734호, 2019. 1. 30.,...  False  False
# 2                       금융위원회(규제개혁법무담당관), 02-2100-2802   True  False
# 3                                               제1장 총칙  False  False
# 4    제1조(목적) 이 훈령은 금융위원회 및 금융유관기관이 금융회사등에 대한 금융규제를 ...   True  False
# ..                                                 ...    ...    ...
# 577  2. 「정보보호산업의 진흥에 관한 법률」 제23조에 따라 지정된 정보보호전문서비스 ...  False   True
# 578                                        3. 침해사고대응기관  False  False
# 579                                   4. 금융위원장이 지정하는 자   True  False
# 580  ② 금융회사 및 전자금융업자는 시행령 제11조의5제3항에 따른 전자금융기반시설의 취...   True  False
# 581  ③ 금융위원장은 취약점 분석·평가 결과보고서에 근거하여 필요시 금융회사 및 전자금융...   True  False
#
# [582 rows x 3 columns]

# %%
help(find_words_from_file)
# Out:
# Help on module find_words_from_file:
#
# NAME
#     find_words_from_file
#
# FUNCTIONS
#     find(obj_file, dst_file, find_words)
#         find: 지정 파일로부터 특정단어를 찾아 dataframe형태로 출력해주는 모듈
#         obj_file: 목적 대상 파일(txt 파일 권장, 인코딩 utf-8)
#         dst_file: csv로 출력해 저장할 파일의 이름(출력을 안할때는 공백("")으로 할 것)
#         find_words: 찾을 단어 list 입력
#         ex) find_words_from_file('input.txt', './ouput.csv', ['word1', 'word2'])
#
#         return 값: 결과 dataframe
#
#         ---
#         dependency: pandas
#
# FILE
#     c:\projects\find_words_from_file.py
